# %% [markdown]
# # About the Data

# %% [markdown]
# This database contains 14 attributes . In particular, the Cleveland database is the only one that has been used by ML researchers to this date. The "goal" field refers to the presence of heart disease in the patient. It is integer valued from 0 (no presence) to 4. Experiments with the Cleveland database have concentrated on simply attempting to distinguish presence (values 1,2,3,4) from absence (value 0).

# %% [markdown]
# # About the Variables

# %% [markdown]
# #1.age- age in years
# #2.sex- (1 = male; 0 = female)
# #3.cp- chest pain type
# #4.trestbps- resting blood pressure (in mm Hg on admission to the hospital)
# #5.chol- serum cholestoral in mg/dl
# #6.fbs- (fasting blood sugar > 120 mg/dl) (1 = true; 0 = false)
# #7.restecg- resting electrocardiographic results
# #8.thalach- maximum heart rate achieved
# #9.exang- exercise induced angina (1 = yes; 0 = no)
# #10.oldpeak- ST depression induced by exercise relative to rest
# #11.slope- the slope of the peak exercise ST segment
# #12.ca- number of major vessels (0-3) colored by flourosopy
# #13.thal- 3 = normal; 6 = fixed defect; 7 = reversable defect
# #14.target- 1 or 0

# %% [markdown]
# # Loading essential libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Reading The Data

# %%
#Reading the data
df=pd.read_csv("heart.csv")
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
#Checking null values
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# We have no missing data.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %% [markdown]
# All the data is numerical. So, there is no need of encoding.

# %% [markdown]
# # Summary Statistics

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %% [markdown]
# #Age of people is between 29-77.
# #Standard deviation is under normal limits for every variable age being the exception.

# %%
df['sex'].value_counts()
# Out:
# 1    207
# 0     96
# Name: sex, dtype: int64

# %%
df['cp'].value_counts()
# Out:
# 0    143
# 2     87
# 1     50
# 3     23
# Name: cp, dtype: int64

# %%
df['fbs'].value_counts()
# Out:
# 0    258
# 1     45
# Name: fbs, dtype: int64

# %%
df['exang'].value_counts()
# Out:
# 0    204
# 1     99
# Name: exang, dtype: int64

# %%
df['ca'].value_counts()
# Out:
# 0    175
# 1     65
# 2     38
# 3     20
# 4      5
# Name: ca, dtype: int64

# %%
df['thal'].value_counts()
# Out:
# 2    166
# 3    117
# 1     18
# 0      2
# Name: thal, dtype: int64

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %% [markdown]
# # Univariate Analysis

# %%
df.hist(figsize=(20,20))
plt.show()

# %% [markdown]
# #Observation:
# 1. Max observations are between age 45-65.
# 2. We can observe some of the graphs are skewed like Cholestrol  DistanceFromHome, Maximum Heart Rate Achieved, Resting Blood Pressure.
# 3. There are no uneccesary variables visible.

# %%
#No of patients and non-patients for both genders
plt.subplots(figsize=(12,8))
sns.countplot(x='target',hue='sex',data=df)
plt.title("No of Heart Patients of different Gender")
plt.xlabel("0 = No Disease, 1 = Disease")
plt.ylabel("No of Patients")
plt.legend(["Female","Male"]);
plt.xticks(rotation=0);

# %% [markdown]
# While males have higher no of heart diseases but it's the women that have higher ratio of having a heart disease.

# %%
#No of patients and non-patients for every chest pain type
plt.subplots(figsize=(12,8))
sns.countplot(x='cp',hue='target',data=df)
plt.title("No of Heart Patients of different Chest pain type")
plt.xlabel("Chest Pain type")
plt.ylabel("No of people")
plt.legend(["Disease","No disease"]);
plt.xticks(rotation=0);

# %% [markdown]
# People having Chest Pain type 0 have highest no of heart diseases.

# %%
sns.set(style="whitegrid")
sns.violinplot(df["chol"])
plt.show()

# %% [markdown]
# Most observation of Serum Cholestrol is between the range 200-300.

# %%
sns.set(style="whitegrid")
sns.violinplot(df["thalach"])
plt.show()

# %% [markdown]
# Most observation of  Maximum Heart Rate Achieved is between the range 120-180.

# %%
sns.set(style="whitegrid")
sns.violinplot(df["trestbps"])
plt.show()

# %% [markdown]
# Most observation of Resting Blood Pressure is between the range 100-160.

# %% [markdown]
# # Bi Variate Analysis

# %% [markdown]
# Age vs Cholestrol Level

# %%
plt.figure(figsize=(10,6))
plt.scatter(df.age,df.chol,c="salmon");
plt.title("AGE vs CHOLESTROL GRAPH")
plt.xlabel("Age")
plt.ylabel("Cholestrol Level")
plt.show()

# %% [markdown]
# Cholestrol levels are hisgher in people aged above 40.

# %%
plt.figure(figsize=(10,6))
plt.scatter(df.age,df.thalach,c="red");
plt.title("Age vs  Maximum Heart Rate Achieved GRAPH")
plt.xlabel("Age")
plt.ylabel("Maximum Heart Rate Achieved")
plt.show()

# %% [markdown]
# Heart rate starts decreasing with increasing aged specially after 50.

# %% [markdown]
# # Checking Correlation

# %%
cor=df.corr()
cor
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %%
plt.figure(figsize=(15,30))
sns.heatmap(cor,annot=True,cmap="winter")

# %% [markdown]
# ##Most positive Correlations are with:
# 1. cp
# 2. thalach
# 3. slope
#
# ##Most negative Correlations are with:
# 1. exang
# 2. thal
# 3. oldpeak

# %% [markdown]
# # Plotting Outliers

# %%
df["chol"].plot.box()

# %%
df["oldpeak"].plot.box()

# %%
df["thalach"].plot.box()

# %%
df["trestbps"].plot.box()

# %% [markdown]
# We can see some outliers in Resting blood pressure(trestbps) and Cholestrol levels

# %% [markdown]
# # Removing Outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[0.9521966 , 0.68100522, 1.97312292, ..., 0.71442887, 2.14887271,
#         0.91452919],
#        [1.91531289, 0.68100522, 1.00257707, ..., 0.71442887, 0.51292188,
#         0.91452919],
#        [1.47415758, 1.46841752, 0.03203122, ..., 0.71442887, 0.51292188,
#         0.91452919],
#        ...,
#        [1.50364073, 0.68100522, 0.93851463, ..., 1.24459328, 1.12302895,
#         1.09345881],
#        [0.29046364, 0.68100522, 0.93851463, ..., 0.26508221, 1.12302895,
#         1.09345881],
#        [0.29046364, 1.46841752, 0.03203122, ..., 0.26508221, 0.51292188,
#         1.09345881]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 28,  48,  85,  92, 158, 163, 164, 204, 220, 221, 223, 246, 248,
#        251, 272, 281], dtype=int64), array([ 4, 12,  4, 11, 11, 11, 11,  9,  4,  9,  3,  4,  3, 11,  7, 12],
#       dtype=int64))

# %%
df_n=df[(z<3).all(axis=1)]

# %%
print("New Shape :",df_n.shape,"Old Shape :",df.shape)
# Out:
# New Shape : (287, 14) Old Shape : (303, 14)

# %% [markdown]
# # Checking Correlation

# %% [markdown]
# # Checking and Treating Skewness

# %%
df_n.skew()
# Out:
# age        -0.184321
# sex        -0.825426
# cp          0.491220
# trestbps    0.530712
# chol        0.245591
# fbs         2.051982
# restecg     0.155787
# thalach    -0.473864
# exang       0.738876
# oldpeak     0.984256
# slope      -0.503916
# ca          1.211037
# thal       -0.190864
# target     -0.204199
# dtype: float64

# %%
#Spliitng the data and target variable
df_x=df_n.drop(['target'],axis=1)
y=df_n['target']

# %%
#Treating skewness via log method
for col in df_x.columns:
    if df_x[col].skew()>0.55:
        df_x[col]=np.log1p(df_x[col])

# %% [markdown]
# # Model Training

# %%
#Scaling the input variable
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(df_x)
x=pd.DataFrame(x,columns=df_x.columns)

# %% [markdown]
# As our data target variable is categorical there we will be using classification techniques.

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
from sklearn.metrics import accuracy_score

# %%
from sklearn.model_selection import KFold, cross_val_score, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier, RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
#Coverting to train and test data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
#Fitting diffrent models to data 
models= [LogisticRegression(),SVC(),DecisionTreeClassifier(),KNeighborsClassifier(),GaussianNB()]
for m in models:
    m.fit(x_train,y_train)
    print("Score of ",m," :",m.score(x_train,y_train))
    predm=m.predict(x_test)
    print('Scores')
    print("Accuracy Score : ",accuracy_score(y_test,predm))     
    print("--------------------------------------------------------------------------------------------")
    print("\n")
# Out:
# Score of  LogisticRegression()  : 0.868995633187773
# Scores
# Accuracy Score :  0.8620689655172413
# --------------------------------------------------------------------------------------------
#
#
# Score of  SVC()  : 0.9344978165938864
# Scores
# Accuracy Score :  0.7758620689655172
# --------------------------------------------------------------------------------------------
#
#
# Score of  DecisionTreeClassifier()  : 1.0
# Scores
# Accuracy Score :  0.7931034482758621
# --------------------------------------------------------------------------------------------
#
#
# Score of  KNeighborsClassifier()  : 0.8777292576419214
# Scores
# Accuracy Score :  0.8103448275862069
# --------------------------------------------------------------------------------------------
#
#
# Score of  GaussianNB()  : 0.8558951965065502
# Scores
# Accuracy Score :  0.8103448275862069
# --------------------------------------------------------------------------------------------

# %% [markdown]
# We are getting best results with Decision Tree Classifier but we will validating it with Cross Val method.

# %%
#Cross Validating
models= [LogisticRegression(),SVC(),DecisionTreeClassifier(),KNeighborsClassifier(),GaussianNB()]
for m in models:
    score=cross_val_score(m,x,y,cv=4,scoring="accuracy")
    print("Score of ",m," is :",score)
    print("Mean Score : ",score.mean())
    print("Standard Deviation : ",score.std())
    print("--------------------------------------------------------------------------------------------")
    print("\n")
# Out:
# Score of  LogisticRegression()  is : [0.83333333 0.88888889 0.80555556 0.84507042]
# Mean Score :  0.8432120500782472
# Standard Deviation :  0.030022607216004266
# --------------------------------------------------------------------------------------------
#
#
# Score of  SVC()  is : [0.875      0.88888889 0.77777778 0.78873239]
# Mean Score :  0.8325997652582159
# Standard Deviation :  0.04973942572434574
# --------------------------------------------------------------------------------------------
#
#
# Score of  DecisionTreeClassifier()  is : [0.83333333 0.80555556 0.70833333 0.77464789]
# Mean Score :  0.7804675273865415
# Standard Deviation :  0.04653335566552551
# --------------------------------------------------------------------------------------------
#
#
# Score of  KNeighborsClassifier()  is : [0.81944444 0.83333333 0.76388889 0.78873239]
# Mean Score :  0.8013497652582159
# Standard Deviation :  0.02698555793500004
# ...

# %% [markdown]
# After Cross Validation we are getting best scores using Logistic Regression.

# %%
#LogisticRegression is the best model so we will find out it's best parameter using GridSearchCV
lr=LogisticRegression()
parameters = {'penalty':['l1', 'l2', 'elasticnet', 'none'],
          'random_state':range(0,100)}
clf=GridSearchCV(lr,parameters)
clf.fit(x,y)
clf.best_params_
# Out:
# {'penalty': 'l2', 'random_state': 0}

# %% [markdown]
# Best parameters: Penalty:'l2' & random_state=0

# %%
#Using LogisticRegression method with best parameters
lr=LogisticRegression(penalty='l2',random_state=0)
lr.fit(x_train,y_train)
print("Score of ",lr," :",lr.score(x_train,y_train))
predlr=lr.predict(x_test)
print('Scores')
print("Accuracy Score : ",accuracy_score(y_test,predlr))
print("Classification Report : \n",classification_report(y_test,predlr))
print("Confusion_matrix : ",confusion_matrix(y_test,predlr))
print("--------------------------------------------------------------------------------------------")
print("\n")
# Out:
# Score of  LogisticRegression(random_state=0)  : 0.868995633187773
# Scores
# Accuracy Score :  0.8620689655172413
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.86      0.78      0.82        23
#            1       0.86      0.91      0.89        35
#
#     accuracy                           0.86        58
#    macro avg       0.86      0.85      0.85        58
# weighted avg       0.86      0.86      0.86        58
#
# Confusion_matrix :  [[18  5]
#  [ 3 32]]
# --------------------------------------------------------------------------------------------

# %% [markdown]
# We are getting an accuracy of 86% using Logistic Regression. For increasing the accuracy of our model further we will be using Ensemble Techniques.

# %% [markdown]
# # Ensemble Methods

# %%
#Random Forest
rf=RandomForestClassifier(n_estimators=20,random_state=0)
rf.fit(x_train,y_train)
predrf=rf.predict(x_test)
print('Scores')
print("Accuracy Score : ",accuracy_score(y_test,predrf))
print("Classification Report : \n",classification_report(y_test,predrf))
print("Confusion_matrix : ",confusion_matrix(y_test,predrf))
print("--------------------------------------------------------------------------------------------")
print("\n")
# Out:
# Scores
# Accuracy Score :  0.7586206896551724
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.66      0.83      0.73        23
#            1       0.86      0.71      0.78        35
#
#     accuracy                           0.76        58
#    macro avg       0.76      0.77      0.76        58
# weighted avg       0.78      0.76      0.76        58
#
# Confusion_matrix :  [[19  4]
#  [10 25]]
# --------------------------------------------------------------------------------------------

# %%
ad=AdaBoostClassifier(n_estimators=20,random_state=0)
ad.fit(x_train,y_train)
predad=ad.predict(x_test)
print('Scores')
print("Accuracy Score : ",accuracy_score(y_test,predad))
print("Classification Report : \n",classification_report(y_test,predad))
print("Confusion_matrix : ",confusion_matrix(y_test,predad))
print("--------------------------------------------------------------------------------------------")
print("\n")
# Out:
# Scores
# Accuracy Score :  0.8103448275862069
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.75      0.78      0.77        23
#            1       0.85      0.83      0.84        35
#
#     accuracy                           0.81        58
#    macro avg       0.80      0.81      0.80        58
# weighted avg       0.81      0.81      0.81        58
#
# Confusion_matrix :  [[18  5]
#  [ 6 29]]
# --------------------------------------------------------------------------------------------

# %% [markdown]
# This shows that the accuracy score remains best when we are using Logistic Regression model.

# %% [markdown]
# # Best Model For Prediction : Logistic Regression

# %% [markdown]
# # AUC-ROC CURVE

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
y_pred_prob=lr.predict_proba(x_test)[:,1]
fpr,tpr,thresholds=roc_curve(y_test,y_pred_prob)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label="Logistic Regression")
plt.xlabel("False Positive Rate")
plt.xlabel("True Positive Rate")
plt.title("Logistic Regression")
plt.show()
auc_score=roc_auc_score(y_test,predlr)
print(auc_score)
# Out:
# 0.848447204968944

# %% [markdown]
# # Saving the Model

# %%
import joblib
joblib.dump(lr,"Heart_Disease.pkl")
# Out:
# ['Heart_Disease.pkl']
